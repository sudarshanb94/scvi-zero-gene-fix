# %%
import scanpy as sc
import pandas as pd
import pickle as pkl

# %%
pd.read_pickle('drug_drug_distances.pkl')
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.read_pickle('drug_drug_distances.pkl')
#
# File ~/miniconda/envs/vci/lib/python3.12/site-packages/pandas/io/pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     199     with warnings.catch_warnings(record=True):
#     200         # We want to silence any warnings about, e.g. moved modules.
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#     207     return pc.load(handles.handle, encoding=None)
#
# UnpicklingError: pickle data was truncated

# %%
import matplotlib.pyplot as plt

# Create a cleaner bar plot with same data
fig, ax = plt.subplots(figsize=(4, 5))  # Maintain same aspect ratio as original image

# Bar data
labels = ['sets', 'pert_mean']
values = [0.83, 0.60]  # Slight adjustment to match original visual more closely

# Colors
colors = ['royalblue', 'goldenrod']  # Orange and green, matching the original style

# Plot
bars = ax.bar(labels, values, color=colors)

# Title and labels
ax.set_title('ARI between Real and Predicted Drug Distances', fontsize=12)
ax.set_ylabel('Adjusted Rand Index', fontsize=11)
ax.set_ylim(0, 1.0)

# Save figure
output_clean_path = "cleaned_bar_plot.svg"
plt.tight_layout()
plt.savefig(output_clean_path, dpi=300)

output_clean_path
# Out:
# 'cleaned_bar_plot.svg'
